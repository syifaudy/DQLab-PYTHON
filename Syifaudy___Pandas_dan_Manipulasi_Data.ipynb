# %%
# mengimport pandas ke notebook

import pandas as pd
import numpy as np # berhubungan dg array atau deret bil (utuk perhitungan matematika)

# %% [markdown]
# # Membuat table sendiri

# %%
data_siswa = pd.DataFrame(
    [
      ['Ridho',173,73],
      ['Rudy',160,53 ]
        ], columns=['Nama', 'Tinggi', 'Berat']
) # list dalam list

data_siswa
# Out:
#     Nama  Tinggi  Berat
# 0  Ridho     173     73
# 1   Rudy     160     53

# %%
data_siswa2 = pd.DataFrame(
    {
        "Nama": ['Ridho','Rudy'],
        "Tinggi": [173,160]
    }
) # pake dictionary
data_siswa2
# Out:
#     Nama  Tinggi
# 0  Ridho     173
# 1   Rudy     160

# %%
# membaca data dengan read_csv

df = pd.read_csv('SuperStore.csv') # disimpan dalam bentuk variabel df agar bisa di run
df
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2     CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4     US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
# ...              ...         ...          ...              ...       ...
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.2480
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.9600
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.5760
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.6000
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.1600
#
#       Quantity  Discount    Profit         Category Sub-Category  \
# ...

# %%
# menampilkan 5 baris teratas by default

df.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         Product_Name  Order_Date   Ship_Date  \
# 0                  Bush Somerset Collection Bookcase   11/8/2019  11/11/2019
# ...

# %%
df.tail()
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID    Sales  \
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.248
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.960
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.576
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.600
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.160
#
#       Quantity  Discount   Profit         Category Sub-Category  \
# 9989         3       0.2   4.1028        Furniture  Furnishings
# 9990         2       0.0  15.6332        Furniture  Furnishings
# 9991         2       0.2  19.3932       Technology       Phones
# 9992         4       0.0  13.3200  Office Supplies        Paper
# 9993         2       0.0  72.9480  Office Supplies   Appliances
#
#                                            Product_Name Order_Date  Ship_Date  \
# ...

# %% [markdown]
# #Mengubah tipe data dlm kolom

# %%
# cara akses info tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   object
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   float64
#  7   Profit          9994 non-null   float64
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   datetime64[ns]
#  12  Ship_Date       9994 non-null   datetime64[ns]
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
# ...

# %% [markdown]
# ## Mengubah tipe data menjadi tanggal

# %%
# mengubah order date dan ship date menjadi tipe data tanggal

df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'])

# %%
df['Postal_Code'] #Series
# Out:
# 0       42420
# 1       42420
# 2       90036
# 3       33311
# 4       33311
#         ...
# 9989    33180
# 9990    92627
# 9991    92627
# 9992    92627
# 9993    92683
# Name: Postal_Code, Length: 9994, dtype: category
# Categories (632, int64): [1040, 1453, 1752, 1810, ..., 98632, 98661, 99207, 99301]

# %%
# mengubah postal code menjadi object karena kategorikal


#harus didefinisiin
df['Postal_Code'] = df['Postal_Code'].astype('category')

# %%
# menampilkan tipe data dari df yaitu DataFrame = 2 dimensi

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# kolom kolom dari DataFrame adalah Series = 1 dimensi

type(df['Customer_ID'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Order_ID','Sales','Quantity']])
# Out:
# pandas.core.frame.DataFrame

# %%
# loc[baris,kolom]
df.loc[:, ['Order_ID','Sales','Quantity']] # semua kolom
# Out:
#             Order_ID     Sales  Quantity
# 0     CA-2019-152156  261.9600         2
# 1     CA-2019-152156  731.9400         3
# 2     CA-2019-138688   14.6200         2
# 3     US-2018-108966  957.5775         5
# 4     US-2018-108966   22.3680         2
# ...              ...       ...       ...
# 9989  CA-2017-110422   25.2480         3
# 9990  CA-2020-121258   91.9600         2
# 9991  CA-2020-121258  258.5760         2
# 9992  CA-2020-121258   29.6000         4
# 9993  CA-2020-119914  243.1600         2
#
# [9994 rows x 3 columns]

# %%
# loc[baris,kolom]
df.loc[:10, ['Order_ID','Sales','Quantity']] # semua kolom
# Out:
#           Order_ID      Sales  Quantity
# 0   CA-2019-152156   261.9600         2
# 1   CA-2019-152156   731.9400         3
# 2   CA-2019-138688    14.6200         2
# 3   US-2018-108966   957.5775         5
# 4   US-2018-108966    22.3680         2
# 5   CA-2017-115812    48.8600         7
# 6   CA-2017-115812     7.2800         4
# 7   CA-2017-115812   907.1520         6
# 8   CA-2017-115812    18.5040         3
# 9   CA-2017-115812   114.9000         5
# 10  CA-2017-115812  1706.1840         9

# %%
# iloc[index baris, index kolom] berdasarkan index
df.iloc[:10, [0,2,3]] # semua kolom
# Out:
#          Order_ID  Postal_Code       Product_ID
# 0  CA-2019-152156        42420  FUR-BO-10001798
# 1  CA-2019-152156        42420  FUR-CH-10000454
# 2  CA-2019-138688        90036  OFF-LA-10000240
# 3  US-2018-108966        33311  FUR-TA-10000577
# 4  US-2018-108966        33311  OFF-ST-10000760
# 5  CA-2017-115812        90032  FUR-FU-10001487
# 6  CA-2017-115812        90032  OFF-AR-10002833
# 7  CA-2017-115812        90032  TEC-PH-10002275
# 8  CA-2017-115812        90032  OFF-BI-10003910
# 9  CA-2017-115812        90032  OFF-AP-10002892

# %% [markdown]
# # Menampilkan list colomn

# %%
# menampilkan daftar kolom dari df

df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Postal_Code', 'Product_ID', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Category', 'Sub-Category',
#        'Product_Name', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Customer_Name',
#        'Segment', 'Country/Region', 'City', 'State', 'Region'],
#       dtype='object')

# %%
# kolomnya mau dijadiin huruf kecil

df_columns = df.columns.str.lower()
df_columns
# Out:
# Index(['order_id', 'customer_id', 'postal_code', 'product_id', 'sales',
#        'quantity', 'discount', 'profit', 'category', 'sub-category',
#        'product_name', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'country/region', 'city', 'state', 'region'],
#       dtype='object')

# %%
# memilih kolom tertentu dari df

df['Category']
# Out:
# 0             Furniture
# 1             Furniture
# 2       Office Supplies
# 3             Furniture
# 4       Office Supplies
#              ...
# 9989          Furniture
# 9990          Furniture
# 9991         Technology
# 9992    Office Supplies
# 9993    Office Supplies
# Name: Category, Length: 9994, dtype: object

# %%
# memilih lebih dari satu kolom

nama_kolom = ['Category','Customer_ID','City']
df[nama_kolom]
# Out:
#              Category Customer_ID             City
# 0           Furniture    CG-12520        Henderson
# 1           Furniture    CG-12520        Henderson
# 2     Office Supplies    DV-13045      Los Angeles
# 3           Furniture    SO-20335  Fort Lauderdale
# 4     Office Supplies    SO-20335  Fort Lauderdale
# ...               ...         ...              ...
# 9989        Furniture    TB-21400            Miami
# 9990        Furniture    DB-13060       Costa Mesa
# 9991       Technology    DB-13060       Costa Mesa
# 9992  Office Supplies    DB-13060       Costa Mesa
# 9993  Office Supplies    CC-12220      Westminster
#
# [9994 rows x 3 columns]

# %%
# slicing menggunakan loc
# syntax: df.loc[baris,kolom]
# pada loc, cara memilih kolom adalah dengan memanggil nama kolom tersebut

# menampilkan 10 baris pertama dari kolom Order_ID
df.loc[:10,'Order_ID']
# Out:
# 0     CA-2019-152156
# 1     CA-2019-152156
# 2     CA-2019-138688
# 3     US-2018-108966
# 4     US-2018-108966
# 5     CA-2017-115812
# 6     CA-2017-115812
# 7     CA-2017-115812
# 8     CA-2017-115812
# 9     CA-2017-115812
# 10    CA-2017-115812
# Name: Order_ID, dtype: object

# %%
# menampilkan 5 baris teratas dari nama-nama
# kolom yang telah didefinisikan

nama_kolom = ['Category','Customer_ID','City']
df.loc[:5,nama_kolom]
# Out:
#           Category Customer_ID             City
# 0        Furniture    CG-12520        Henderson
# 1        Furniture    CG-12520        Henderson
# 2  Office Supplies    DV-13045      Los Angeles
# 3        Furniture    SO-20335  Fort Lauderdale
# 4  Office Supplies    SO-20335  Fort Lauderdale
# 5        Furniture    BH-11710      Los Angeles

# %%
# pada list kolom df, kolom dengan index 4 adalah 'Sales'

df.columns[4]
# Out:
# 'Sales'

# %%
# pada iloc, kolom dipanggil dengan nomor indexnya

df.iloc[:10,4]
# Out:
# 0    261.9600
# 1    731.9400
# 2     14.6200
# 3    957.5775
# 4     22.3680
# 5     48.8600
# 6      7.2800
# 7    907.1520
# 8     18.5040
# 9    114.9000
# Name: Sales, dtype: float64

# %%
# memanggil 10 baris pertama dari
# kolom dengan index 1,3,5,7

df.iloc[:10,[1,3,5,7]]
# Out:
#   Customer_ID       Product_ID  Quantity    Profit
# 0    CG-12520  FUR-BO-10001798         2   41.9136
# 1    CG-12520  FUR-CH-10000454         3  219.5820
# 2    DV-13045  OFF-LA-10000240         2    6.8714
# 3    SO-20335  FUR-TA-10000577         5 -383.0310
# 4    SO-20335  OFF-ST-10000760         2    2.5164
# 5    BH-11710  FUR-FU-10001487         7   14.1694
# 6    BH-11710  OFF-AR-10002833         4    1.9656
# 7    BH-11710  TEC-PH-10002275         6   90.7152
# 8    BH-11710  OFF-BI-10003910         3    5.7825
# 9    BH-11710  OFF-AP-10002892         5   34.4700

# %% [markdown]
# # Filtering

# %% [markdown]
# ###Classic Style

# %%
# Untuk melakukan filtering, gunakan syntax: df[kondisi]

# contoh, memfilter sales dengan nilai lebih dari 100

df[df['Sales'] > 100].head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 7  CA-2017-115812    BH-11710        90032  TEC-PH-10002275  907.1520
# 9  CA-2017-115812    BH-11710        90032  OFF-AP-10002892  114.9000
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 3         5      0.45 -383.0310        Furniture       Tables
# 7         6      0.20   90.7152       Technology       Phones
# 9         5      0.00   34.4700  Office Supplies   Appliances
#
#                                         Product_Name Order_Date  Ship_Date  \
# 0                  Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# ...

# %% [markdown]
# ###Query Style

# %%
# pake query
df.query('Sales > 500').head()
# Out:
#           Order_ID Customer_ID  Postal_Code       Product_ID      Sales  \
# 1   CA-2019-152156    CG-12520        42420  FUR-CH-10000454   731.9400
# 3   US-2018-108966    SO-20335        33311  FUR-TA-10000577   957.5775
# 7   CA-2017-115812    BH-11710        90032  TEC-PH-10002275   907.1520
# 10  CA-2017-115812    BH-11710        90032  FUR-TA-10001539  1706.1840
# 11  CA-2017-115812    BH-11710        90032  TEC-PH-10002033   911.4240
#
#     Quantity  Discount    Profit    Category Sub-Category  \
# 1          3      0.00  219.5820   Furniture       Chairs
# 3          5      0.45 -383.0310   Furniture       Tables
# 7          6      0.20   90.7152  Technology       Phones
# 10         9      0.20   85.3092   Furniture       Tables
# 11         4      0.20   68.3568  Technology       Phones
#
#                                          Product_Name  Order_Date   Ship_Date  \
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...   11/8/2019  11/11/2019
# ...

# %% [markdown]
# ###Multiple Condition

# %%
# memfilter dengan dua atau lebih kondisi
# ingat: untuk menghindari kesalahan penulisan ekspresi, gunakan tanda kurung

# gunakan bitwise operator
# & untuk and
# | untuk or
# ~ untuk not

# memfilter transaksi dengan sales > 100 dari kategori Furniture
df[(df['Sales'] > 100) & (df['Category'] == 'Furniture')].head()
# Out:
#           Order_ID Customer_ID  Postal_Code       Product_ID      Sales  \
# 0   CA-2019-152156    CG-12520        42420  FUR-BO-10001798   261.9600
# 1   CA-2019-152156    CG-12520        42420  FUR-CH-10000454   731.9400
# 3   US-2018-108966    SO-20335        33311  FUR-TA-10000577   957.5775
# 10  CA-2017-115812    BH-11710        90032  FUR-TA-10001539  1706.1840
# 24  CA-2018-106320    EB-13870        84057  FUR-TA-10000577  1044.6300
#
#     Quantity  Discount    Profit   Category Sub-Category  \
# 0          2      0.00   41.9136  Furniture    Bookcases
# 1          3      0.00  219.5820  Furniture       Chairs
# 3          5      0.45 -383.0310  Furniture       Tables
# 10         9      0.20   85.3092  Furniture       Tables
# 24         3      0.00  240.2649  Furniture       Tables
#
#                                          Product_Name Order_Date  Ship_Date  \
# 0                   Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# ...

# %%
df.query('Sales > 500 & Quantity > 10').head()
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 251   CA-2019-145625    KC-16540        92037  TEC-AC-10003832  3347.370
# 412   CA-2020-117457    KH-16510        94110  FUR-BO-10001972  1336.829
# 660   CA-2018-146563    CB-12025        76017  OFF-ST-10001511   724.080
# 949   US-2020-110576    RB-19795        19120  FUR-TA-10004154  2065.320
# 1013  US-2018-126214    JS-15880        98103  FUR-TA-10003748  1618.370
#
#       Quantity  Discount    Profit         Category Sub-Category  \
# 251         13      0.00  636.0003       Technology  Accessories
# 412         13      0.15   31.4548        Furniture    Bookcases
# 660         14      0.20 -135.7650  Office Supplies      Storage
# 949         12      0.40 -619.5960        Furniture       Tables
# 1013        13      0.00  356.0414        Furniture       Tables
#
#                                            Product_Name  Order_Date  \
# ...

# %%
# contoh negasi ~
df[~(df['Category']=='Furniture')].head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID    Sales  \
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.620
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.368
# 6  CA-2017-115812    BH-11710        90032  OFF-AR-10002833    7.280
# 7  CA-2017-115812    BH-11710        90032  TEC-PH-10002275  907.152
# 8  CA-2017-115812    BH-11710        90032  OFF-BI-10003910   18.504
#
#    Quantity  Discount   Profit         Category Sub-Category  \
# 2         2       0.0   6.8714  Office Supplies       Labels
# 4         2       0.2   2.5164  Office Supplies      Storage
# 6         4       0.0   1.9656  Office Supplies          Art
# 7         6       0.2  90.7152       Technology       Phones
# 8         3       0.2   5.7825  Office Supplies      Binders
#
#                                         Product_Name Order_Date  Ship_Date  \
# 2  Self-Adhesive Address Labels for Typewriters b... 2019-06-12 2019-06-16
# ...

# %%
# contoh or
df[(df['City']=='Henderson') | (df['City']=='Los Angeles')].head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID   Sales  Quantity  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.96         2
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.94         3
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.62         2
# 5  CA-2017-115812    BH-11710        90032  FUR-FU-10001487   48.86         7
# 6  CA-2017-115812    BH-11710        90032  OFF-AR-10002833    7.28         4
#
#    Discount    Profit         Category Sub-Category  \
# 0       0.0   41.9136        Furniture    Bookcases
# 1       0.0  219.5820        Furniture       Chairs
# 2       0.0    6.8714  Office Supplies       Labels
# 5       0.0   14.1694        Furniture  Furnishings
# 6       0.0    1.9656  Office Supplies          Art
#
#                                         Product_Name Order_Date  Ship_Date  \
# 0                  Bush Somerset Collection Bookcase 2019-11-08 2019-11-11
# ...

# %% [markdown]
# ## Sorting

# %% [markdown]
# ### Cara mengisi argumen:
#
#
# 1.   Positional argumen (berdasarkan posisi)
# 2.   Keyword argumen (berdasarkan keyword)

# %%
# sorting berdasarkan tanggal
# secara default, ascending = True
# sehingga diurutkan dari tanggal terkecil ke terbesar

df.sort_values(by='Order_Date')
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID    Sales  \
# 7980  CA-2017-103800    DP-13000        77095  OFF-PA-10000174   16.448
# 739   CA-2017-112326    PO-19195        60540  OFF-LA-10003223   11.784
# 740   CA-2017-112326    PO-19195        60540  OFF-ST-10002743  272.736
# 741   CA-2017-112326    PO-19195        60540  OFF-BI-10004094    3.540
# 1759  CA-2017-141817    MB-18085        19143  OFF-AR-10003478   19.536
# ...              ...         ...          ...              ...      ...
# 5091  CA-2020-156720    JM-15580        80538  OFF-FA-10003472    3.024
# 908   CA-2020-143259    PO-18865        10009  OFF-BI-10003684   52.776
# 907   CA-2020-143259    PO-18865        10009  TEC-PH-10004774   90.930
# 1296  CA-2020-115427    EB-13975        94533  OFF-BI-10002103   13.904
# 906   CA-2020-143259    PO-18865        10009  FUR-BO-10003441  323.136
#
#       Quantity  Discount   Profit         Category Sub-Category  \
# ...

# %%
df.sort_values(by='Order_Date', ascending=False)
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID    Sales  \
# 906   CA-2020-143259    PO-18865        10009  FUR-BO-10003441  323.136
# 907   CA-2020-143259    PO-18865        10009  TEC-PH-10004774   90.930
# 1296  CA-2020-115427    EB-13975        94533  OFF-BI-10002103   13.904
# 1297  CA-2020-115427    EB-13975        94533  OFF-BI-10004632   20.720
# 645   CA-2020-126221    CC-12430        47201  OFF-AP-10002457  209.300
# ...              ...         ...          ...              ...      ...
# 1759  CA-2017-141817    MB-18085        19143  OFF-AR-10003478   19.536
# 741   CA-2017-112326    PO-19195        60540  OFF-BI-10004094    3.540
# 739   CA-2017-112326    PO-19195        60540  OFF-LA-10003223   11.784
# 740   CA-2017-112326    PO-19195        60540  OFF-ST-10002743  272.736
# 7980  CA-2017-103800    DP-13000        77095  OFF-PA-10000174   16.448
#
#       Quantity  Discount   Profit         Category Sub-Category  \
# ...

# %%
# sorting berdasarkan dua kolom

df.sort_values(by=['Category','Sub-Category']).head()
# Out:
#            Order_ID Customer_ID  Postal_Code       Product_ID      Sales  \
# 0    CA-2019-152156    CG-12520        42420  FUR-BO-10001798   261.9600
# 27   US-2018-150630    TB-21520        19140  FUR-BO-10004834  3083.4300
# 38   CA-2018-117415    SN-20710        77041  FUR-BO-10002545   532.3992
# 189  CA-2018-102281    MP-17470        10035  FUR-BO-10002613   899.1360
# 192  CA-2018-102281    MP-17470        10035  FUR-BO-10002545   626.3520
#
#      Quantity  Discount     Profit   Category Sub-Category  \
# 0           2      0.00    41.9136  Furniture    Bookcases
# 27          7      0.50 -1665.0522  Furniture    Bookcases
# 38          3      0.32   -46.9764  Furniture    Bookcases
# 189         4      0.20   112.3920  Furniture    Bookcases
# 192         3      0.20    46.9764  Furniture    Bookcases
#
#                                           Product_Name  Order_Date  \
# 0                    Bush Somerset Collection Bookcase   11/8/2019
# ...

# %%
# Sorting menggunakan dua kolom
# Category secara menurun
# Sub-Category secara menaik

df.sort_values(by=['Category','Sub-Category'], ascending=[False, True]).head()
# Out:
#           Order_ID Customer_ID  Postal_Code       Product_ID  Sales  Quantity  \
# 26  CA-2019-121755    EH-13945        90049  TEC-AC-10003027  90.57         3
# 44  CA-2019-118255    ON-18715        55122  TEC-AC-10000171  45.98         2
# 47  CA-2019-169194    LH-16900        19901  TEC-AC-10002167  45.00         3
# 59  CA-2019-111682    TB-21055        12180  TEC-AC-10002167  30.00         2
# 62  CA-2018-135545    KM-16720        90004  TEC-AC-10004633  13.98         2
#
#     Discount   Profit    Category Sub-Category  \
# 26       0.0  11.7741  Technology  Accessories
# 44       0.0  19.7714  Technology  Accessories
# 47       0.0   4.9500  Technology  Accessories
# 59       0.0   3.3000  Technology  Accessories
# 62       0.0   6.1512  Technology  Accessories
#
#                                          Product_Name  Order_Date   Ship_Date  \
# 26   Imation 8GB Mini TravelDrive USB 2.0 Flash Drive   1/16/2019   1/20/2019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   int64
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   float64
#  7   Profit          9994 non-null   float64
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   datetime64[ns]
#  12  Ship_Date       9994 non-null   datetime64[ns]
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
# ...

# %% [markdown]
# ## Deskriptive Statistik
#
# *   Data Normal biasanya nilai mean hampir sama dg q2/mediannya
# - kalau skewness: median di puncak, mean di ekor
# *   kalau dr data dibawah, menunjukkan bahwa sales itu right skewness

# %%
df.describe() # akan muncul kolom yg sifatnya numerik
# Out:
#         Postal_Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.371023    229.858001     3.789574     0.156203    28.656896
# std    32063.704510    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# include object = yg ditampilkan objek

df.describe(include='O')
# Out:
#               Order_ID Customer_ID       Product_ID         Category  \
# count             9994        9994             9994             9994
# unique            5009         793             1862                3
# top     CA-2020-100111    WB-21850  OFF-PA-10001970  Office Supplies
# freq                14          37               19             6026
#
#        Sub-Category     Product_Name       Ship_Mode  Customer_Name   Segment  \
# count          9994             9994            9994           9994      9994
# unique           17             1817               4            793         3
# top         Binders  Staple envelope  Standard Class  William Brown  Consumer
# freq           1523               48            5968             37      5191
#
#        Country/Region           City       State Region
# count            9994           9994        9994   9994
# unique              1            531          49      4
# top     United States  New York City  California   West
# ...

# %% [markdown]
# #Value Count

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Ship_Mode'].value_counts(normalize=True)*100
# Out:
# Ship_Mode
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: proportion, dtype: float64

# %%
# dibulatkan 2 angka dibekalang koma

np.round(df['Ship_Mode'].value_counts(normalize=True)*100,2)
# Out:
# Ship_Mode
# Standard Class    59.72
# Second Class      19.46
# First Class       15.39
# Same Day           5.43
# Name: proportion, dtype: float64

# %% [markdown]
# # Sumarizing Data

# %%
sumarize_df = df.groupby(['Order_Date','Region','Category']).agg({'Sales':'sum','Quantity':'sum'})

# %%
# untuk dibuat kolom
# inplace untuk saving data terbaru tanpa asign
sumarize_df.reset_index(inplace=True)

# %%
sumarize_df
# Out:
#      Order_Date   Region         Category     Sales  Quantity
# 0      1/1/2020  Central        Furniture   452.164         9
# 1      1/1/2020  Central  Office Supplies   506.338        32
# 2      1/1/2020     East        Furniture    48.896         4
# 3      1/1/2020     West        Furniture   474.430        11
# 4     1/10/2017    South        Furniture    51.940         1
# ...         ...      ...              ...       ...       ...
# 5170   9/9/2020    South        Furniture    14.136         3
# 5171   9/9/2020    South  Office Supplies  1130.108        21
# 5172   9/9/2020     West        Furniture   243.920         5
# 5173   9/9/2020     West  Office Supplies   202.598        23
# 5174   9/9/2020     West       Technology   159.960         4
#
# [5175 rows x 5 columns]

# %%
df[['Category','Sales']].groupby(by=['Category']).sum()
# Out:
#                        Sales
# Category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %%
df[['Category','Sub-Category','Sales']].groupby(by=['Category','Sub-Category']).mean()
# Out:
#                                     Sales
# Category        Sub-Category
# Furniture       Bookcases      503.859633
#                 Chairs         532.332420
#                 Furnishings     95.825668
#                 Tables         648.794771
# Office Supplies Appliances     230.755710
#                 Art             34.068834
#                 Binders        133.560560
#                 Envelopes       64.867724
#                 Fasteners       13.936774
#                 Labels          34.303055
#                 Paper           57.284092
#                 Storage        264.590553
#                 Supplies       245.650200
# Technology      Accessories    215.974604
#                 Copiers       2198.941618
#                 Machines      1645.553313
#                 Phones         371.211534

# %% [markdown]
# ## Iterasi

# %%
# iterasi dengan list of columns

# karena df.columns menghasilkan list of columns
# maka df.columns dapat digunakan sebagai iterator

# iterasi berdasarkan kolom berguna saat kita ingin
#mengaplikasikan operasi berulang terhadap kolom tertentu

for kolom in df.columns:
  print(kolom)
# Out:
# Order_ID
# Customer_ID
# Postal_Code
# Product_ID
# Sales
# Quantity
# Discount
# Profit
# Category
# Sub-Category
# Product_Name
# Order_Date
# Ship_Date
# Ship_Mode
# Customer_Name
# Segment
# Country/Region
# City
# State
# Region

# %%
# disamping itu, iterasi juga dapat dilakukan terhadap index
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
# contoh
for idx in df.index:
  print(df['Order_ID'][idx], df['Order_Date'][idx])
# Out:
# Streaming output truncated to the last 5000 lines.
# CA-2018-153038 2018-12-18 00:00:00
# CA-2017-132227 2017-11-04 00:00:00
# CA-2020-155824 2020-03-10 00:00:00
# CA-2020-155824 2020-03-10 00:00:00
# CA-2019-129238 2019-01-31 00:00:00
# CA-2019-129238 2019-01-31 00:00:00
# CA-2020-159688 2020-05-07 00:00:00
# CA-2019-136126 2019-05-24 00:00:00
# CA-2019-136126 2019-05-24 00:00:00
# CA-2019-155033 2019-10-07 00:00:00
# CA-2017-156006 2017-04-30 00:00:00
# CA-2018-158659 2018-11-10 00:00:00
# CA-2018-169796 2018-11-09 00:00:00
# CA-2018-169796 2018-11-09 00:00:00
# CA-2018-102876 2018-09-07 00:00:00
# CA-2018-102876 2018-09-07 00:00:00
# CA-2018-102876 2018-09-07 00:00:00
# US-2020-139647 2020-05-11 00:00:00
# US-2020-160465 2020-07-21 00:00:00
# US-2020-160465 2020-07-21 00:00:00
# US-2020-160465 2020-07-21 00:00:00
# CA-2017-153850 2017-11-24 00:00:00
# CA-2017-153850 2017-11-24 00:00:00
# CA-2017-127558 2017-11-15 00:00:00
# CA-2017-127558 2017-11-15 00:00:00
# ...

# %%
# iterasi baris per baris dengan iterrows()

for index, row in df.iterrows():
  print(row['Order_ID'], row['Order_Date'])
# Out:
# Streaming output truncated to the last 5000 lines.
# CA-2018-153038 2018-12-18 00:00:00
# CA-2017-132227 2017-11-04 00:00:00
# CA-2020-155824 2020-03-10 00:00:00
# CA-2020-155824 2020-03-10 00:00:00
# CA-2019-129238 2019-01-31 00:00:00
# CA-2019-129238 2019-01-31 00:00:00
# CA-2020-159688 2020-05-07 00:00:00
# CA-2019-136126 2019-05-24 00:00:00
# CA-2019-136126 2019-05-24 00:00:00
# CA-2019-155033 2019-10-07 00:00:00
# CA-2017-156006 2017-04-30 00:00:00
# CA-2018-158659 2018-11-10 00:00:00
# CA-2018-169796 2018-11-09 00:00:00
# CA-2018-169796 2018-11-09 00:00:00
# CA-2018-102876 2018-09-07 00:00:00
# CA-2018-102876 2018-09-07 00:00:00
# CA-2018-102876 2018-09-07 00:00:00
# US-2020-139647 2020-05-11 00:00:00
# US-2020-160465 2020-07-21 00:00:00
# US-2020-160465 2020-07-21 00:00:00
# US-2020-160465 2020-07-21 00:00:00
# CA-2017-153850 2017-11-24 00:00:00
# CA-2017-153850 2017-11-24 00:00:00
# CA-2017-127558 2017-11-15 00:00:00
# CA-2017-127558 2017-11-15 00:00:00
# ...

# %%
# export data

my_df = df.loc[:10,['Customer_Name']]

my_df.to_csv('my_df.csv')
